# %% [markdown]
# #### Imports

# %%
import requests
import pandas as pd 
import sqlalchemy

# %% [markdown]
# #### Requests & CURL

# %%
headers = {
    'Connection': 'keep-alive',
    'sec-ch-ua': '^\\^',
    'Accept': 'application/json, text/javascript, */*; q=0.01',
    'sec-ch-ua-mobile': '?0',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36 Edg/96.0.1054.62',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'Origin': 'https://ontariohockeyleague.com',
    'Sec-Fetch-Site': 'cross-site',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Dest': 'empty',
    'Referer': 'https://ontariohockeyleague.com/',
    'Accept-Language': 'en-GB,en;q=0.9,en-US;q=0.8,de;q=0.7',
}

params = (
    ('feed', 'modulekit'),
    ('view', 'statviewtype'),
    ('type', 'topscorers'),
    ('key', '2976319eb44abe94'),
    ('fmt', 'json'),
    ('client_code', 'ohl'),
    ('lang', 'en'),
    ('league_code', ''),
    ('season_id', '68'),
    ('first', '0'),
    ('limit', '100'),
    ('sort', 'active'),
    ('stat', 'all'),
    ('order_direction', ''),
)

response = requests.get('https://lscluster.hockeytech.com/feed/', headers=headers, params=params)

# %% [markdown]
# #### Check Status Code

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# #### Create JSON object

# %%
results_json = response.json()

# %% [markdown]
# #### Output Keys

# %%
results_json.keys()
# Out:
# dict_keys(['SiteKit'])

# %% [markdown]
# #### Find your Data

# %% [markdown]
# - Name
# - Age
# - Height
# - Games Played
# - Goals
# - Points
# - Penalty Minutes
# - Home Country

# %%
results = results_json['SiteKit']['Statviewtype']
len(results)
# Out:
# 100

# %%
# name
results[0]['name']
# Out:
# 'Marco Rossi'

# %%
# age
results[0]['age']
# Out:
# '20'

# %%
# height
results[0]['height']
# Out:
# '5.09'

# %%
# games played
results[0]['games_played']
# Out:
# '56'

# %%
# goals
results[0]['goals']
# Out:
# '39'

# %%
# points
results[0]['points']
# Out:
# '120'

# %%
# penalty minutes
results[0]['penalty_minutes']
# Out:
# '40'

# %%
# home country
results[0]['homecntry']
# Out:
# 'Austria'

# %% [markdown]
# #### Loop through results and append data inside a list

# %%
name = []
age = []
height = []
games_played = []
goals = []
points  = []
penalty_minutes = []
home_country = []


for result in results:
    
    # name
    name.append(result['name'])
    
    # age
    age.append(result['age'])
    
    # height
    height.append(result['height'])
    
    # games played
    games_played.append(result['games_played'])
    
    # goals
    goals.append(result['goals'])
    
    # points
    points.append(result['points'])
    
    # penalty minutes
    penalty_minutes.append(result['penalty_minutes'])
    
    # home country
    home_country.append(result['homecntry'])

# %% [markdown]
# #### Pandas Dataframe

# %%
hockey_df = pd.DataFrame({'name':name, 'age':age, 'height': height, 'games_played': games_played,
                         'goals':goals, 'points':points, 'penalty_minutes':penalty_minutes, 'home_country':home_country})

# %%
hockey_df
# Out:
#                           name age height games_played goals points  \
# 0                  Marco Rossi  20   5.09           56    39    120
# 1                Cole Perfetti  20   5.10           61    37    111
# 2             Connor McMichael  21   6.00           52    47    102
# 3      Philip Tomasino (total)  20   6.00           62    40    100
# 4               Arthur Kaliyev  20   6.02           57    44     98
# 5                Pavel Gogolev  22   6.01           63    45     96
# 6              Joseph Garreffa  22   5.07           52    36     90
# 7                   Jack Quinn  20   6.01           62    52     89
# 8               Austen Keating  23   6.00           58    32     89
# 9               Nick Robertson  20   5.09           46    55     86
# 10         Akil Thomas (total)  22   6.00           49    24     84
# 11               Brett Neumann  23   5.09           62    45     83
# 12                  Cam Hillis  21   5.11           62    24     83
# 13             Quinton Byfield  19   6.04           45    32     82
# 14            Noel Hoefenmayer  23   6.01           58    26     82
# 15              Tyson Foerster  20   6.02           62    36     80
# 16                 Cole Coskey  23   6.01           62    34     80
# 17           Evgeniy Oksentyuk  21   5.07           58    33     78
# 18                Sean Josling  23   6.00           60    32     78
# 19               Riley Damiani  22   5.10           61    28     78
# 20                 Maxim Golod  21   5.11           63    25     78
# 21          Mitchell Hoelscher  22   6.00           62    34     76
# 22                Ryan Merkley  21   5.11           60    15     76
# 23               Damien Giroux  22   5.10           61    44     75
# 24     Semyon Der-Arguchintsev  21   5.10           55    12     75
# 25                 Chad Yetman  22   5.11           61    43     74
# 26                 David Levin  22   5.10           57    27     73
# 27                Blake Murray  20   6.02           63    35     72
# 28               Cole Schwindt  21   6.03           57    28     71
# 29                  Liam Hawel  23   6.04           54    23     71
# ..                         ...  ..    ...          ...   ...    ...
# 70        Tyler Tucker (total)  22   6.02           55    17     56
# 71                 Jack Wismer  22   6.00           62    27     54
# 72                 Jake Durham  23   5.10           63    22     54
# 73             Connor Corcoran  21   6.03           62    19     54
# 74                  Tye Kartye  21   6.01           64    25     53
# 75        Jason Willms (total)  23   6.00           60    22     53
# 76                 Aidan Dudas  21   5.08           48    15     53
# 77  Billy Constantinou (total)  21   6.00           60     9     53
# 78               Kaleb Pearson  21   5.11           62    28     52
# 79       Shane Bulitka (total)  22   5.11           62    23     52
# 80             Keean Washkurak  20   5.10           49    22     52
# 81              Axel Bergkvist  22   5.09           62     9     52
# 82                 Cole MacKay  20   5.11           64    25     51
# 83              Daniel D'Amico  21   5.10           61    23     50
# 84              Jaromir Pytlik  20   6.02           56    22     50
# 85             Macauley Carson  23   6.01           63    22     50
# 86                   Liam Kirk  22  6.00.           47    21     50
# 87              Robert Calisti  21   5.09           64    18     50
# 88                Tag Bertuzzi  21   6.01           57    25     47
# 89      Ethan Cardwell (total)  19   5.11           63    23     47
# 90                 Aidan Brown  22   6.01           57    20     47
# 91         Serron Noel (total)  21   6.06           48    18     47
# 92              Jamie Drysdale  20   5.11           49     9     47
# 93           Kyen Sopa (total)  21   5.09           52    19     46
# 94               Owen Robinson  22   6.00           63    15     46
# 95                Kyle MacLean  23   6.01           51    13     46
# 96              Logan Morrison  19   6.00           59    23     45
# 97             Austen Swankler  20   6.00           59    18     45
# 98                 Cole Purboo  22   6.03           59    20     44
# 99           Richard Whittaker  22   6.00           57    19     44
#
#    penalty_minutes   home_country
# 0               40        Austria
# 1               16         Canada
# 2               26         Canada
# 3               32         Canada
# 4               28  United States
# 5               66         Russia
# 6                2         Canada
# 7               32         Canada
# 8               10         Canada
# 9               40  United States
# 10              56  United States
# 11              20         Canada
# 12              43         Canada
# 13              44
# 14              37         Canada
# 15              53         Canada
# 16              41  United States
# 17              51
# 18              58         Canada
# 19              32         Canada
# 20              34         Canada
# 21              51         Canada
# 22              48         Canada
# 23              22         Canada
# 24              23         Russia
# 25               8         Canada
# 26              39         Canada
# 27              58         Canada
# 28              31         Canada
# 29              51         Canada
# ..             ...            ...
# 70              87         Canada
# 71              12         Canada
# 72              42         Canada
# 73              50         Canada
# 74              28         Canada
# 75              53         Canada
# 76              28         Canada
# 77              49         Canada
# 78              36         Canada
# 79              35         Canada
# 80              62         Canada
# 81              23            SWE
# 82              42         Canada
# 83              46         Canada
# 84              36     Czech Rep.
# 85              71         Canada
# 86              25        England
# 87              64         Canada
# 88              23         Canada
# 89              41         Canada
# 90              77         Canada
# 91              36         Canada
# 92              24         Canada
# 93              50    Switzerland
# 94              16         Canada
# 95              64  United States
# 96              18         Canada
# 97              61  United States
# 98              16         Canada
# 99              78         Canada
#
# [100 rows x 8 columns]

# %% [markdown]
# #### Export

# %%
# csv
hockey_df.to_csv('hockey.csv',sep=';',index=False)

# %%
# json
hockey_df.to_json('hockey.json', orient='records', lines=True)

# %%
# excel
# hockey_df.to_excel('hockey.xlsx',index=False)

# %%
# postgresql
# engine = sqlalchemy.create_engine('postgres://postgres:12345@localhost:5432')
# hockey_df.to_sql('hockey', engine, index=False)
